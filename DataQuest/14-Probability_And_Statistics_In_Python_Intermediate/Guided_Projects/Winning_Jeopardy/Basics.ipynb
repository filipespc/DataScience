# %%
import pandas as pd

# %% [markdown]
# # Exploring the Dataset

# %%
jeopardy = pd.read_csv("jeopardy.csv")
jeopardy.head(5)
# Out:
#    Show Number    Air Date      Round                         Category  Value  \
# 0         4680  2004-12-31  Jeopardy!                          HISTORY   $200
# 1         4680  2004-12-31  Jeopardy!  ESPN's TOP 10 ALL-TIME ATHLETES   $200
# 2         4680  2004-12-31  Jeopardy!      EVERYBODY TALKS ABOUT IT...   $200
# 3         4680  2004-12-31  Jeopardy!                 THE COMPANY LINE   $200
# 4         4680  2004-12-31  Jeopardy!              EPITAPHS & TRIBUTES   $200
#
#                                             Question      Answer
# 0  For the last 8 years of his life, Galileo was ...  Copernicus
# 1  No. 2: 1912 Olympian; football star at Carlisl...  Jim Thorpe
# 2  The city of Yuma in this state has a record av...     Arizona
# 3  In 1963, live on "The Art Linkletter Show", th...  McDonald's
# 4  Signer of the Dec. of Indep., framer of the Co...  John Adams

# %%
jeopardy.columns
# Out:
# Index(['Show Number', ' Air Date', ' Round', ' Category', ' Value',
#        ' Question', ' Answer'],
#       dtype='object')

# %%
new_columns = []
for idx,column in enumerate(jeopardy.columns):
    if column[0] == " ":
        new_columns.append(column[1:])
    else:
        new_columns.append(column)
        
jeopardy.columns = new_columns
jeopardy.columns
# Out:
# Index(['Show Number', 'Air Date', 'Round', 'Category', 'Value', 'Question',
#        'Answer'],
#       dtype='object')

# %%
jeopardy.dtypes
# Out:
# Show Number     int64
# Air Date       object
# Round          object
# Category       object
# Value          object
# Question       object
# Answer         object
# dtype: object

# %% [markdown]
# # Normalizing Columns

# %%
import string

# %%
def norm_text(text):
    translator = str.maketrans('','',string.punctuation)
    return text.lower().translate(translator)

# %%
jeopardy["clean_question"] = jeopardy["Question"].apply(norm_text)
jeopardy["clean_question"].head(5)
# Out:
# 0    for the last 8 years of his life galileo was u...
# 1    no 2 1912 olympian football star at carlisle i...
# 2    the city of yuma in this state has a record av...
# 3    in 1963 live on the art linkletter show this c...
# 4    signer of the dec of indep framer of the const...
# Name: clean_question, dtype: object

# %%
jeopardy["clean_answer"] = jeopardy["Answer"].apply(norm_text)
jeopardy["clean_answer"].head(5)
# Out:
# 0    copernicus
# 1    jim thorpe
# 2       arizona
# 3     mcdonalds
# 4    john adams
# Name: clean_answer, dtype: object

# %%
def norm_value(value):
    translator = str.maketrans('','',string.punctuation)
    try:
        return int(value.translate(translator))
    except Exception:
        return 0

# %%
jeopardy["clean_value"] = jeopardy["Value"].apply(norm_value)
jeopardy["clean_value"].head(5)
# Out:
# 0    200
# 1    200
# 2    200
# 3    200
# 4    200
# Name: clean_value, dtype: int64

# %%
jeopardy["Air Date"] = pd.to_datetime(jeopardy["Air Date"])
jeopardy["Air Date"].head(5)
# Out:
# 0   2004-12-31
# 1   2004-12-31
# 2   2004-12-31
# 3   2004-12-31
# 4   2004-12-31
# Name: Air Date, dtype: datetime64[ns]

# %% [markdown]
# # Working on the "looking for answers in questions" strategy

# %%
def answer_in_question(row):
    split_answer = row["clean_answer"].split(" ")
    split_question = row["clean_question"].split(" ")
    
    while "the" in split_answer:
        split_answer.remove("the")
    if len(split_answer) == 0:
        return 0

    match_count = 0
    for each in split_answer:
        if each in split_question:
            match_count += 1
    
    return match_count/len(split_answer)

# %%
jeopardy["answer_in_question"] = jeopardy.apply(answer_in_question, axis=1)

# %%
jeopardy["answer_in_question"].mean()
# Out:
# 0.059737124385356791

# %% [markdown]
# # Analysis on "looking for answers in questions" strategy
# The "looking for answers in questions" strategy consists on trying to trying to find the answers for the questions in the words of the questions itself.
#
# Unfortunately, this strategy isn't very promissing, as (in averge) the words on the answer appears only about **6%** of the time in the question.
#
# Obs.: The word "the" was disregarded in this analysis, as it is really common on both questions and answers and could lead to a misinterpretation.

# %% [markdown]
# # Working on "looking for old questions" strategy

# %%
jeopardy.sort_values("Air Date",inplace=True)
jeopardy.head(100)
# Out:
#        Show Number   Air Date             Round               Category  \
# 19325           10 1984-09-21   Final Jeopardy!        U.S. PRESIDENTS
# 19301           10 1984-09-21  Double Jeopardy!           LABOR UNIONS
# 19302           10 1984-09-21  Double Jeopardy!                   1789
# 19303           10 1984-09-21  Double Jeopardy!          TOURIST TRAPS
# 19304           10 1984-09-21  Double Jeopardy!             LITERATURE
# 19305           10 1984-09-21  Double Jeopardy!               HOMONYMS
# 19306           10 1984-09-21  Double Jeopardy!              TV TRIVIA
# 19307           10 1984-09-21  Double Jeopardy!                   1789
# 19308           10 1984-09-21  Double Jeopardy!          TOURIST TRAPS
# 19309           10 1984-09-21  Double Jeopardy!             LITERATURE
# 19310           10 1984-09-21  Double Jeopardy!               HOMONYMS
# 19311           10 1984-09-21  Double Jeopardy!              TV TRIVIA
# 19312           10 1984-09-21  Double Jeopardy!          TOURIST TRAPS
# 19313           10 1984-09-21  Double Jeopardy!             LITERATURE
# 19314           10 1984-09-21  Double Jeopardy!               HOMONYMS
# 19315           10 1984-09-21  Double Jeopardy!              TV TRIVIA
# 19316           10 1984-09-21  Double Jeopardy!          TOURIST TRAPS
# 19317           10 1984-09-21  Double Jeopardy!             LITERATURE
# 19318           10 1984-09-21  Double Jeopardy!               HOMONYMS
# 19319           10 1984-09-21  Double Jeopardy!              TV TRIVIA
# 19320           10 1984-09-21  Double Jeopardy!                   1789
# 19321           10 1984-09-21  Double Jeopardy!          TOURIST TRAPS
# 19322           10 1984-09-21  Double Jeopardy!             LITERATURE
# 19323           10 1984-09-21  Double Jeopardy!               HOMONYMS
# 19300           10 1984-09-21         Jeopardy!                 SPORTS
# 19324           10 1984-09-21  Double Jeopardy!              TV TRIVIA
# 19299           10 1984-09-21         Jeopardy!             "B" MOVIES
# 19297           10 1984-09-21         Jeopardy!  "JACKS" OF ALL TRADES
# 19274           10 1984-09-21         Jeopardy!              GEOGRAPHY
# 19275           10 1984-09-21         Jeopardy!            DOUBLE TALK
# ...            ...        ...               ...                    ...
# 8580            62 1984-12-04  Double Jeopardy!                  BIRDS
# 8582            62 1984-12-04  Double Jeopardy!               POLITICS
# 8583            62 1984-12-04  Double Jeopardy!                 EUROPE
# 8584            62 1984-12-04  Double Jeopardy!              BIG BANDS
# 8585            62 1984-12-04  Double Jeopardy!              NOTORIOUS
# 8586            62 1984-12-04  Double Jeopardy!                  BIRDS
# 8587            62 1984-12-04  Double Jeopardy!                   BEES
# 8588            62 1984-12-04  Double Jeopardy!               POLITICS
# 8589            62 1984-12-04  Double Jeopardy!                 EUROPE
# 8590            62 1984-12-04  Double Jeopardy!              BIG BANDS
# 8591            62 1984-12-04  Double Jeopardy!              NOTORIOUS
# 8592            62 1984-12-04  Double Jeopardy!                   BEES
# 8593            62 1984-12-04  Double Jeopardy!               POLITICS
# 8594            62 1984-12-04  Double Jeopardy!                 EUROPE
# 8595            62 1984-12-04  Double Jeopardy!              BIG BANDS
# 8581            62 1984-12-04  Double Jeopardy!                   BEES
# 8596            62 1984-12-04  Double Jeopardy!              NOTORIOUS
# 8564            62 1984-12-04         Jeopardy!            A LA "CART"
# 8562            62 1984-12-04         Jeopardy!                 COLORS
# 8563            62 1984-12-04         Jeopardy!                 SPORTS
# 8547            62 1984-12-04         Jeopardy!                   FOOD
# 8548            62 1984-12-04         Jeopardy!           MOVIE TRIVIA
# 8549            62 1984-12-04         Jeopardy!        WASHINGTON D.C.
# 8550            62 1984-12-04         Jeopardy!                 COLORS
# 8551            62 1984-12-04         Jeopardy!                 SPORTS
# 8552            62 1984-12-04         Jeopardy!            A LA "CART"
# 8553            62 1984-12-04         Jeopardy!                   FOOD
# 8546            62 1984-12-04         Jeopardy!            A LA "CART"
# 8555            62 1984-12-04         Jeopardy!        WASHINGTON D.C.
# 8554            62 1984-12-04         Jeopardy!           MOVIE TRIVIA
#
#         Value                                           Question  \
# 19325    None  Adventurous 26th president, he was 1st to ride...
# 19301    $200           Notorious labor leader missing since '75
# 19302    $200  Washington proclaimed Nov. 26, 1789 this first...
# 19303    $200  Both Ferde Grofe' & the Colorado River dug thi...
# 19304    $200  Depending on the book, he could be a "Jones", ...
# 19305    $200                 Hindu hierarchy or a play's actors
# 19306    $200  Last season, this series mourned the loss of S...
# 19307    $400       Why April 28th was a bad day for Capt. Bligh
# 19308    $400  Seaside resort that has a monopoly on East Coa...
# 19309    $400  He wrote "The 3 Musketeers"; his son wrote "Ca...
# 19310    $400                                 Near or a purchase
# 19311    $400          He went from the Ponderosa to the prairie
# 19312    $600  Since '27, stars have made good impressions at...
# 19313    $600     Where you can't go again in Thomas Wolfe title
# 19314    $600            A fixed look, or Ginger Rogers' partner
# 19315    $600                   In 1970 he had a "Goodtime Hour"
# 19316    $800  A thrilling destination for tight-rope walkers...
# 19317    $800  Irving's bird-like hero chased by the Headless...
# 19318  $1,000                                 Didn't see the fog
# 19319    $800  Jackie Gleason show that rejected titles "The ...
# 19320   $1000  Now totaling over $1 trillion, it began 11 day...
# 19321   $1000  Tourists know this Catholic mission as Davy Cr...
# 19322   $1000                              Shaw's scorched saint
# 19323   $1000        Where ships dock or what a jury consists of
# 19300    $500  Boxer whose life was portrayed in "Somebody Up...
# 19324   $1000  In court, he'd always make mincemeat of Hamilt...
# 19299    $500  Sensitive Mart Crowley treatment of gays march...
# 19297    $500  2nd generation pop singer, he's sung on every ...
# 19274    $100                                   Formerly Formosa
# 19275    $100  Not a Hawaiian cow, but a dress worn by Hawaii...
# ...       ...                                                ...
# 8580     $400  Depending on the species, a bird can have 940 ...
# 8582     $400  Nickname of late Washington Senator Henry Jackson
# 8583     $600  19th century Sardinia took the lead in unifyin...
# 8584     $600  As famous for his marriages as his music; once...
# 8585     $600  32 inmates & 11 guards were killed in '71 upri...
# 8586     $600  All 16 species of the Hawaiian honeycreeper ar...
# 8587     $600                  A large crowd of bees on the move
# 8588     $600  U.S. ambassadors to this country have included...
# 8589     $800    In '67 this last king of Greece went into exile
# 8590     $800            Benny Goodman got good "vibes" from him
# 8591     $800  Despite his "fortunate" nickname, this gangste...
# 8592   $1,900                 The 3 classes of a honeybee colony
# 8593     $800  Florida Congressman who champions the senior c...
# 8594   $1,000  Only predominanty Muslim country entirely in E...
# 8595    $1000  "Royal" bandleader whose first two names were ...
# 8581     $400                     Common name of an apiculturist
# 8596    $1000  He wrote the Howard Hughes "autobiography" tha...
# 8564     $400  The 1st graduate of the U.S. Naval Academy to ...
# 8562     $400                                Broadway's nickname
# 8563     $400              What the letters in "scuba" stand for
# 8547     $100                  Varieties include Chinese & Dijon
# 8548     $100  Turned down to be an "Our Gang" member, she be...
# 8549     $200  The District's oldest neighborhood, it was nam...
# 8550     $200  Johnny Cash is known for wearing only this col...
# 8551     $200  Tennis serve that touches net before dropping ...
# 8552     $200                              A sideways handspring
# 8553     $200  Type of food that comes in shapes of bow ties,...
# 8546     $100  While 2 of its wheels head toward produce, 1 g...
# 8555     $300  287 miles long, it flows past Washington & ind...
# 8554   $1,000  Number of the sequel <a href="http://www.j-arc...
#
#                                               Answer  \
# 19325                             Theodore Roosevelt
# 19301                                    Jimmy Hoffa
# 19302                                   Thanksgiving
# 19303                               the Grand Canyon
# 19304                                            Tom
# 19305                                 a caste (cast)
# 19306                              Hill Street Blues
# 19307            the day of the mutiny on the Bounty
# 19308                      Atlantic City, New Jersey
# 19309                              (Alexandre) Dumas
# 19310                                       by (buy)
# 19311                                 Michael Landon
# 19312                         Mann's Chinese Theatre
# 19313                                           home
# 19314                              a stare (Astaire)
# 19315                                  Glen Campbell
# 19316                                  Niagara Falls
# 19317                                  Ichabod Crane
# 19318                                  missed (mist)
# 19319                               The Honeymooners
# 19320                              the national debt
# 19321                                      the Alamo
# 19322                                St. Joan of Arc
# 19323                                  piers (peers)
# 19300                                 Rocky Graziano
# 19324                                    Perry Mason
# 19299                           The Boys in the Band
# 19297                                     Jack Jones
# 19274                                         Taiwan
# 19275                                       a muumuu
# ...                                              ...
# 8580                                        feathers
# 8582                                   Scoop Jackson
# 8583                                           Italy
# 8584                                      Artie Shaw
# 8585                                          Attica
# 8586                     the endangered species list
# 8587                                         a swarm
# 8588                                   Great Britain
# 8589                                Constantine (II)
# 8590                                  Lionel Hampton
# 8591                                 "Lucky" Luciano
# 8592                  a drone, a queen, and a worker
# 8593                                   Claude Pepper
# 8594                                         Albania
# 8595                                  Duke Ellington
# 8581                                     a beekeeper
# 8596                                 Clifford Irving
# 8564                                    Jimmy Carter
# 8562                             the Great White Way
# 8563   self-contained underwater breathing apparatus
# 8547                                         mustard
# 8548                                  Shirley Temple
# 8549                                      Georgetown
# 8550                                           black
# 8551                                      a let ball
# 8552                                     a cartwheel
# 8553                                           pasta
# 8546                                 a shopping cart
# 8555                               the Potomac River
# 8554                                       Rocky III
#
#                                           clean_question  \
# 19325  adventurous 26th president he was 1st to ride ...
# 19301            notorious labor leader missing since 75
# 19302  washington proclaimed nov 26 1789 this first n...
# 19303  both ferde grofe  the colorado river dug this ...
# 19304  depending on the book he could be a jones a sa...
# 19305                  hindu hierarchy or a plays actors
# 19306  last season this series mourned the loss of sg...
# 19307        why april 28th was a bad day for capt bligh
# 19308  seaside resort that has a monopoly on east coa...
# 19309    he wrote the 3 musketeers his son wrote camille
# 19310                                 near or a purchase
# 19311          he went from the ponderosa to the prairie
# 19312  since 27 stars have made good impressions at t...
# 19313      where you cant go again in thomas wolfe title
# 19314              a fixed look or ginger rogers partner
# 19315                     in 1970 he had a goodtime hour
# 19316  a thrilling destination for tightrope walkers ...
# 19317  irvings birdlike hero chased by the headless h...
# 19318                                  didnt see the fog
# 19319  jackie gleason show that rejected titles the l...
# 19320  now totaling over 1 trillion it began 11 days ...
# 19321  tourists know this catholic mission as davy cr...
# 19322                               shaws scorched saint
# 19323        where ships dock or what a jury consists of
# 19300  boxer whose life was portrayed in somebody up ...
# 19324  in court hed always make mincemeat of hamilton...
# 19299  sensitive mart crowley treatment of gays march...
# 19297  2nd generation pop singer hes sung on every lo...
# 19274                                   formerly formosa
# 19275  not a hawaiian cow but a dress worn by hawaiia...
# ...                                                  ...
# 8580   depending on the species a bird can have 940 t...
# 8582   nickname of late washington senator henry jackson
# 8583   19th century sardinia took the lead in unifyin...
# 8584   as famous for his marriages as his music once ...
# 8585   32 inmates  11 guards were killed in 71 uprisi...
# 8586   all 16 species of the hawaiian honeycreeper ar...
# 8587                   a large crowd of bees on the move
# 8588   us ambassadors to this country have included a...
# 8589      in 67 this last king of greece went into exile
# 8590               benny goodman got good vibes from him
# 8591   despite his fortunate nickname this gangster w...
# 8592                  the 3 classes of a honeybee colony
# 8593   florida congressman who champions the senior c...
# 8594   only predominanty muslim country entirely in e...
# 8595   royal bandleader whose first two names were ed...
# 8581                      common name of an apiculturist
# 8596   he wrote the howard hughes autobiography that ...
# 8564   the 1st graduate of the us naval academy to be...
# 8562                                  broadways nickname
# 8563                 what the letters in scuba stand for
# 8547                    varieties include chinese  dijon
# 8548   turned down to be an our gang member she becam...
# 8549   the districts oldest neighborhood it was named...
# 8550   johnny cash is known for wearing only this col...
# 8551   tennis serve that touches net before dropping ...
# 8552                               a sideways handspring
# 8553   type of food that comes in shapes of bow ties ...
# 8546   while 2 of its wheels head toward produce 1 go...
# 8555   287 miles long it flows past washington  induc...
# 8554   number of the sequel a hrefhttpwwwjarchivecomm...
#
#                                        clean_answer  clean_value  \
# 19325                            theodore roosevelt            0
# 19301                                   jimmy hoffa          200
# 19302                                  thanksgiving          200
# 19303                              the grand canyon          200
# 19304                                           tom          200
# 19305                                  a caste cast          200
# 19306                             hill street blues          200
# 19307           the day of the mutiny on the bounty          400
# 19308                      atlantic city new jersey          400
# 19309                               alexandre dumas          400
# 19310                                        by buy          400
# 19311                                michael landon          400
# 19312                         manns chinese theatre          600
# 19313                                          home          600
# 19314                               a stare astaire          600
# 19315                                 glen campbell          600
# 19316                                 niagara falls          800
# 19317                                 ichabod crane          800
# 19318                                   missed mist         1000
# 19319                              the honeymooners          800
# 19320                             the national debt         1000
# 19321                                     the alamo         1000
# 19322                                st joan of arc         1000
# 19323                                   piers peers         1000
# 19300                                rocky graziano          500
# 19324                                   perry mason         1000
# 19299                          the boys in the band          500
# 19297                                    jack jones          500
# 19274                                        taiwan          100
# 19275                                      a muumuu          100
# ...                                             ...          ...
# 8580                                       feathers          400
# 8582                                  scoop jackson          400
# 8583                                          italy          600
# 8584                                     artie shaw          600
# 8585                                         attica          600
# 8586                    the endangered species list          600
# 8587                                        a swarm          600
# 8588                                  great britain          600
# 8589                                 constantine ii          800
# 8590                                 lionel hampton          800
# 8591                                  lucky luciano          800
# 8592                   a drone a queen and a worker         1900
# 8593                                  claude pepper          800
# 8594                                        albania         1000
# 8595                                 duke ellington         1000
# 8581                                    a beekeeper          400
# 8596                                clifford irving         1000
# 8564                                   jimmy carter          400
# 8562                            the great white way          400
# 8563   selfcontained underwater breathing apparatus          400
# 8547                                        mustard          100
# 8548                                 shirley temple          100
# 8549                                     georgetown          200
# 8550                                          black          200
# 8551                                     a let ball          200
# 8552                                    a cartwheel          200
# 8553                                          pasta          200
# 8546                                a shopping cart          100
# 8555                              the potomac river          300
# 8554                                      rocky iii         1000
#
#        answer_in_question
# 19325            0.000000
# 19301            0.000000
# 19302            0.000000
# 19303            0.000000
# 19304            0.000000
# 19305            0.333333
# 19306            0.000000
# 19307            0.200000
# 19308            0.000000
# 19309            0.000000
# 19310            0.000000
# 19311            0.000000
# 19312            0.000000
# 19313            0.000000
# 19314            0.333333
# 19315            0.000000
# 19316            0.000000
# 19317            0.000000
# 19318            0.000000
# 19319            0.000000
# 19320            0.000000
# 19321            0.000000
# 19322            0.000000
# 19323            0.000000
# 19300            0.000000
# 19324            0.000000
# 19299            0.000000
# 19297            0.000000
# 19274            0.000000
# 19275            0.500000
# ...                   ...
# 8580             0.000000
# 8582             0.500000
# 8583             0.000000
# 8584             0.000000
# 8585             0.000000
# 8586             0.666667
# 8587             0.500000
# 8588             0.000000
# 8589             0.000000
# 8590             0.000000
# 8591             0.000000
# 8592             0.428571
# 8593             0.000000
# 8594             0.000000
# 8595             0.000000
# 8581             0.000000
# 8596             0.000000
# 8564             0.000000
# 8562             0.000000
# 8563             0.000000
# 8547             0.000000
# 8548             0.000000
# 8549             0.000000
# 8550             0.000000
# 8551             0.000000
# 8552             0.500000
# 8553             0.000000
# 8546             0.000000
# 8555             0.000000
# 8554             0.000000
#
# [100 rows x 11 columns]

# %%
question_overlap = []
terms_used = set()

for idx,row in jeopardy.iterrows():
    split_question = row["clean_question"].split(" ")
    split_question = [word for word in split_question if len(word) >= 6]
    
    match_count = 0
    for word in split_question:
        if word in terms_used:
            match_count += 1
    
    terms_used.update(set(split_question))
    
    if len(split_question) > 0:
        question_overlap.append(match_count/len(split_question))
    else:
        question_overlap.append(0)

jeopardy["question_overlap"] = question_overlap

jeopardy["question_overlap"].mean()
# Out:
# 0.68712428809667803

# %% [markdown]
# # Analysis on "looking for old questions" strategy
# The "looking for old questions" strategy is about studying the old questions subjects believing that similar questions will occur in the new questions.
#
# It seems to be a very good strategy, as about **69%** of the relevant terms (words with more than 6 letters) appears in older questions.

# %% [markdown]
# # Chi Square Test

# %%
def is_high_value(row):
    if row["clean_value"] > 800:
        return 1
    else:
        return 0
    
jeopardy["high_value"] = jeopardy.apply(is_high_value,axis=1)
jeopardy["high_value"].head(25)
# Out:
# 19325    0
# 19301    0
# 19302    0
# 19303    0
# 19304    0
# 19305    0
# 19306    0
# 19307    0
# 19308    0
# 19309    0
# 19310    0
# 19311    0
# 19312    0
# 19313    0
# 19314    0
# 19315    0
# 19316    0
# 19317    0
# 19318    1
# 19319    0
# 19320    1
# 19321    1
# 19322    1
# 19323    1
# 19300    0
# Name: high_value, dtype: int64

# %%
def high_low_word_count(word):
    low_count = 0
    high_count = 0
    for idx,row in jeopardy.iterrows():
        col_split = row["clean_question"].split(" ")
        if word in col_split:
            if row["high_value"] == 1:
                high_count += 1
            else:
                low_count += 1
    return low_count, high_count

observed_expected = []
comparison_terms = list(terms_used)[:5]

for each in comparison_terms:
    observed_expected.append(high_low_word_count(each))
    
observed_expected
# Out:
# [(1, 3), (1, 0), (1, 0), (2, 0), (0, 1)]

# %%
high_value_count = (jeopardy["high_value"] == 1).sum()
low_value_count = (jeopardy["high_value"] == 0).sum()

print(high_value_count)
print(low_value_count)
# Out:
# 5734
# 14265

# %%
from scipy.stats import chisquare

chi_squared = []

for each in observed_expected:
    total = each[0] + each[1]
    total_prop = total/jeopardy.shape[0]
    expected_low = total_prop * low_value_count
    expected_high = total_prop * high_value_count
    chi_squared.append(chisquare(each, [expected_low, expected_high]))

chi_squared
# Out:
# [Power_divergenceResult(statistic=4.1980229752219893, pvalue=0.040471136200959497),
#  Power_divergenceResult(statistic=0.40196284612688399, pvalue=0.52607729857054686),
#  Power_divergenceResult(statistic=0.40196284612688399, pvalue=0.52607729857054686),
#  Power_divergenceResult(statistic=0.80392569225376798, pvalue=0.36992223780795708),
#  Power_divergenceResult(statistic=2.4877921171956752, pvalue=0.11473257634454047)]

# %% [markdown]
# # Analysis on Chi Square Test
# There is just one word that presents a p-value with significance bell
