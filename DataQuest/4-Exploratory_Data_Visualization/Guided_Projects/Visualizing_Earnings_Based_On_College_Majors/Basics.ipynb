# %% [markdown]
# ## CREATING SETUP AND IMPORTING AND CLEANING DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads.iloc[0]
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
raw_data_count = recent_grads.shape[0]
recent_grads.dropna(inplace=True)
cleaned_data_count = recent_grads.shape[0]
print("Raw data number of rows: ",raw_data_count)
print("Cleaned data number of rows", cleaned_data_count)
# Out:
# Raw data number of rows:  173
# Cleaned data number of rows 172

# %% [markdown]
# ## GETTING INTUITION ON DATA - SCATTER

# %%
recent_grads.plot(x="Sample_size", y="Median", kind="scatter", title="Sample Size vs. Median", figsize=(10,10))

# %%
recent_grads.plot(x="Sample_size", y="Unemployment_rate", kind="scatter", title="Sample Size vs. Unemploymet Rate", figsize=(10,10))

# %%
recent_grads.plot(x="Full_time", y="Median", kind="scatter", title="Full Time vs. Median", figsize=(10,10))

# %%
recent_grads.plot(x="ShareWomen", y="Unemployment_rate", kind="scatter", title="Share Women vs. Unemploymet Rate", figsize=(10,10))

# %%
recent_grads.plot(x="Men", y="Median", kind="scatter", title="Men vs. Median", figsize=(10,10))

# %%
recent_grads.plot(x="Women", y="Median", kind="scatter", title="Women vs. Median", figsize=(10,10))

# %%
recent_grads.plot(x="ShareWomen", y="Median", kind="scatter", title="Share Women vs. Median", figsize=(10,10))

# %% [markdown]
# ### Analysis on scatter plots
# It doesn't seem to have any clear relationship between the two cattegory of any of the 6 first plots above.
#
# The last plot, however, indicates that there is a inverse relationship between the share of women in a given cattegory and the median income in that same cattegory. That is: the more women share, the less the median income.

# %% [markdown]
# ## GETTING INTUITION ON DATA - HISTOGRAMS

# %%
recent_grads['Sample_size'].hist(bins=25, figsize=(10,7))

# %%
ax = recent_grads['Median'].hist(bins=40, figsize=(10,7), range=(20000,120000))
ax.set_xticks(np.arange(20000,130000,10000));

# %%
recent_grads['Employed'].hist(bins=25, figsize=(10,7))

# %%
recent_grads['Full_time'].hist(bins=25, figsize=(10,7))

# %%
ax = recent_grads['ShareWomen'].hist(bins=20, figsize=(10,7), range=(0,1))
ax.set_xticks(np.arange(0,1,0.1));
print(recent_grads["ShareWomen"].describe())
# Out:
# count    172.000000
# mean       0.522223
# std        0.231205
# min        0.000000
# 25%        0.336026
# 50%        0.534024
# 75%        0.703299
# max        0.968954
# Name: ShareWomen, dtype: float64

# %%
ax = recent_grads['Unemployment_rate'].hist(bins=20, figsize=(10,7), range=(0,0.2))
ax.set_xticks(np.arange(0,0.25,0.02))

# %%
recent_grads['Men'].hist(bins=25, figsize=(10,7))

# %%
recent_grads['Women'].hist(bins=25, figsize=(10,7))

# %% [markdown]
# ### Analysis on histogram plots
# Almost all plots follow the tendency showed on the sample size plot. Because these data regards to total amount of students, it seems that there is not much information we can take from them.
# However, two plots stand out:
#
# - The Median Plot, where we can take the following informations:
#   - 1 The vast majority of students receive an income from 20k/year to 63k/year.
#   - 2 A huge parte of them receive a income from 30k/year to 43k/year.
#   - 3 The most common income range is from 35k to 38k.
# - The Share Women Plot, where we can take the following informations:
#   - 1 There seems to have more predominantly female courses that predominantly male courses.
#   - 2 There is more highly predominantly male courses (higher than 80%).
# - The Unemployment Rate Plot, where we can take the following informations:
#   - 1 The vast majority of majors have recent graduated students with unemployment rates from 0.02 to 0.12
#   - 2 A big part of the have recent graduated students with unemployment rates from 0.05 to 0.09
#   - 3 Almost no major have recente graduated students with unemployment rates over 0.18

# %% [markdown]
# ## GETTING INTUITION ON DATA - SCATTER MATRIX

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(recent_grads[["Sample_size","Median"]],figsize=(10,10));

# %%
scatter_matrix(recent_grads[["Sample_size","Median","Unemployment_rate"]],figsize=(10,10));

# %%
print(recent_grads.columns)
# Out:
# Index(['Rank', 'Major_code', 'Major', 'Total', 'Men', 'Women',
#        'Major_category', 'ShareWomen', 'Sample_size', 'Employed', 'Full_time',
#        'Part_time', 'Full_time_year_round', 'Unemployed', 'Unemployment_rate',
#        'Median', 'P25th', 'P75th', 'College_jobs', 'Non_college_jobs',
#        'Low_wage_jobs'],
#       dtype='object')

# %%
recent_grads["College_Non_college_rate"] = recent_grads.College_jobs / recent_grads.Non_college_jobs
scatter_matrix(recent_grads[["ShareWomen","Median","Unemployment_rate","College_Non_college_rate"]],figsize=(10,10));

# %%
ax = recent_grads.plot(x="ShareWomen", y="College_Non_college_rate", kind="scatter", title="Share Women vs. Median", figsize=(10,10))

# %% [markdown]
# ### Analysis on scatter matrix plots
# Aside from the already commented relationship between Median and Share Women, there is not that seems to present a clear correlation.
#
# The scatter plot from College_Non_college_rate suggested that it might have a correlation between them, but taking a closer look it looks like it doesn't.

# %% [markdown]
# ## GETTING INTUITION ON DATA - BAR PLOTS

# %%
recent_grads[:10].plot.bar(x="Major",y="ShareWomen")

# %%
recent_grads[-10:].plot.bar(x="Major",y="ShareWomen")

# %% [markdown]
# ### Analysis on bar plots
# It is clear that the share of women in professions that have higher income is much lower that in thos professions that have lower income.

# %% [markdown]
# ## FINAL ANALYSIS
# The most significant analysis in this project regards to the correlation between the share of women in each profession and the median income of this same profession.
#
# One further analysis could look for data that answer to the question: "Do the profession pay less on predominantly female professions because they are predominantly female professions?
